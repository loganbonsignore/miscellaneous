# %% [markdown]
# #### DB Diagram
# https://github.com/near/near-indexer-for-explorer/blob/master/docs/near-indexer-for-explorer-db.png

# %%
import psycopg2  # pip3 install psycopg2
import pandas as pd # pip3 install pandas

# %%
# postgres://public_readonly:nearprotocol@35.184.214.98/testnet_explorer
conn = psycopg2.connect(host="35.184.214.98", database="testnet_explorer", user="public_readonly", password="nearprotocol")

# %%
query = """
SELECT DISTINCT(action_kind)
FROM action_receipt_actions
LIMIT 10
"""

df = pd.read_sql_query(query, conn)
df.head(10)
# Out:
#        action_kind
# 0   CREATE_ACCOUNT
# 1  DEPLOY_CONTRACT
# 2    FUNCTION_CALL
# 3         TRANSFER
# 4            STAKE
# 5          ADD_KEY
# 6       DELETE_KEY
# 7   DELETE_ACCOUNT

# %%
account = "loganbon.testnet"
# account = "evolution4good.testnet"

query_acct = f"""
SELECT *
FROM action_receipt_actions
WHERE receipt_receiver_account_id = '{account}' OR receipt_predecessor_account_id = '{account}'"""

df = pd.read_sql_query(query_acct, conn)
df.head(10)
# Out:
#                                      receipt_id  index_in_action_receipt  \
# 0  GBYfvyGJHJu97QTZTkKZj7Z7uN1BQmCMH6dtwABWPaxa                        0
# 1  GBYfvyGJHJu97QTZTkKZj7Z7uN1BQmCMH6dtwABWPaxa                        1
# 2  GBYfvyGJHJu97QTZTkKZj7Z7uN1BQmCMH6dtwABWPaxa                        2
# 3  2aKqKDqUDLYA7xjyJFDrycieCcfRXy1AmDmCWbWQEt9M                        0
# 4  5ptHnBEcxsWXRbVBkKtdpL7PBiaVKAXEJzGV6UFmSsPv                        0
# 5  A9rH4TmEexody8cqHRgFjJQgy8cPv5tG4F61DLXgKXvG                        0
# 6  DamH6DiGmatovpn2jM1QEcPF1JASpdYWpr5diCfhtMzG                        0
# 7  FPJgEN9YccMfUC8BdonJ6znazXYntPk3y7b8hGEZuJ5N                        0
#
#       action_kind                                               args  \
# 0  CREATE_ACCOUNT                                                 {}
# 1        TRANSFER         {'deposit': '200000001000000000000000000'}
# 2         ADD_KEY  {'access_key': {'nonce': 0, 'permission': {'pe...
# ...

# %%
def calculate_amount(amount):
    # NEAR token has 24 decimals
    return float(int(amount)/(10**24))

# %%
calculate_amount(50000000000000000000000000)
# Out:
# 50.0
